# %% [markdown]
# ## 練習時間
# 相信大家對回歸問題及分類問題都有初步的了解。今天的作業希望大家搜尋有關 multi-label 的案例問題。下圖是電影 "奇異博士" 的分類。可以看到同時有 "Action", "Adventure", "Fantasy" 的類別存在，代表這是個多標籤的問題。

# %% [markdown]
# ![image](https://cdn-images-1.medium.com/max/1000/1*r0gYXMSQf5VhdMyl2bRDyg.png)

# %% [markdown]
# ## 請搜尋目標為多標籤問題 (Multi-label) 的機器學習案例，了解其資料來源、目標以及評估指標為何
# ## Hint: 服飾
#
# 1. 在訓練集(train set)包含六張服飾照片, 每張照片包含黑色牛仔褲, 藍色洋裝, 藍色牛仔褲, 藍色襯衫, 紅色洋裝, 以及紅色襯衫. 所以每張圖片都包含了兩種標籤---顏色(黑,藍,紅)及不同類型的服飾(牛仔褲,洋裝,襯衫). 在訓練完多標籤模型後, 我們可以預測測試集(test sets)照片的標籤機率
# https://www.kaggle.com/vincentman0403/multi-label-classification/data
# ![image.png](attachment:image.png)
#
#
# 2. Toxic Comment Classification Challenge---Identify and classify toxic online comments
#    https://towardsdatascience.com/journey-to-the-center-of-multi-label-classification-384c40229bff
#    https://www.kaggle.com/c/jigsaw-toxic-comment-classification-challenge
#    問題描述：
#    Toxic comment classification is a multi-label text classification problem with a highly imbalanced
#    dataset. We’re challenged to build a multi-labeld model that’s capable of detecting different types of
#    toxicity like threats, obscenity, insults, and identity-based hate. We need to create a model which predicts a
#    probability of each type of toxicity for each comment.
#    評估指標Evaluation Metrics：
#    Initially evaluation metric in the Kaggle challenge was Log-Loss, which was later changed to AUC.
#
# 3.  網路新聞往往含有豐富的語義，一篇文章既可以屬於“經濟”也可以屬於“文化”。給網路新聞打多標籤可以更好地反應文章的真實意義，方便日後的分類和使用。
